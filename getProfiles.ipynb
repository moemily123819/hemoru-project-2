# %%
import pymongo
#from flask_pymongo import PyMongo
from company_info import get_profiles_info
import pprint

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
dblist = client.list_database_names()
if "project_2_DB" in dblist:
    print("The database exists.")
else:
    db = client.project_2_db
    profiles = get_profiles_info()
    for profile in profiles:
        print(profile)
    db.profiles.insert_many([profiles])
# Out:
# profiles_url https://www.quandl.com/api/v3/datatables/ZACKS/CP.json?api_key=LvDnxyb5x2sY2-YHy76Y
# ticker
# comp_name
# comp_desc
# address_line_1
# city
# state_code
# phone_nbr
# email
# comp_url
# zacks_x_ind_desc
# market_val
# tot_revenue_f0
# net_income_f0
# pe_ratio_f1
# div_yield
# rating_strong_buys
# rating_strong_sells
# rating_buys
# rating_sells
# rating_holds

# %%
profiles_list = list(db.profiles.find())

# %%
print(profiles_list[0]["ticker"])
# Out:
# ['AAPL', 'AXP', 'BA', 'CAT', 'CSCO', 'CVX', 'DIS', 'GE', 'GS', 'HD', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PFE', 'PG', 'TRV', 'UNH', 'UTX', 'V', 'VZ', 'WMT', 'XOM']

# %%
prof =[];
for profile in profiles_list:
    prof.append(profile)
    
print(prof)
# Out:
# [{'_id': ObjectId('5ce02b6af6f9031f4c01148f'), 'ticker': ['AAPL', 'AXP', 'BA', 'CAT', 'CSCO', 'CVX', 'DIS', 'GE', 'GS', 'HD', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PFE', 'PG', 'TRV', 'UNH', 'UTX', 'V', 'VZ', 'WMT', 'XOM'], 'comp_name': ['APPLE INC', 'AMER EXPRESS CO', 'BOEING CO', 'CATERPILLAR INC', 'CISCO SYSTEMS', 'CHEVRON CORP', 'DISNEY WALT', 'GENL ELECTRIC', 'GOLDMAN SACHS', 'HOME DEPOT', 'INTL BUS MACH', 'INTEL CORP', 'JOHNSON & JOHNS', 'JPMORGAN CHASE', 'COCA COLA CO', 'MCDONALDS CORP', '3M CO', 'MERCK & CO INC', 'MICROSOFT CORP', 'NIKE INC-B', 'PFIZER INC', 'PROCTER & GAMBL', 'TRAVELERS COS', 'UNITEDHEALTH GP', 'UTD TECHS CORP', 'VISA INC-A', 'VERIZON COMM', 'WALMART INC', 'EXXON MOBIL CRP'], 'comp_desc': ["Apple Inc. is engaged in designing, manufacturing and marketing mobile communication and media devices, personal computers, and portable digital music players. The Company's products and services include iPhone, iPad, Mac, iPod, Apple TV, 
# ...

# %%
p_list = profiles_list[0]
print(p_list)
#ticker_array = profiles_list[1]["ticker"]

#print(ticker_array)
# Out:
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# <ipython-input-39-b04f88ff7a3f> in <module>
# ----> 1 p_list = profiles_list[0]
#       2 print(p_list)
#       3 #ticker_array = profiles_list[1]["ticker"]
#       4
#       5 #print(ticker_array)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py in __getitem__(self, index)
#     573           - `index`: An integer or slice index to be applied to this cursor
#     574         """
# --> 575         self.__check_okay_to_chain()
#     576         self.__empty = False
#     577         if isinstance(index, slice):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\cursor.py in __check_okay_to_chain(self)
#     384         """
#     385         if self.__retrieved or self.__id is not None:
# --> 386             raise InvalidOperation("cannot set options after executing query")
#     387
# ...
